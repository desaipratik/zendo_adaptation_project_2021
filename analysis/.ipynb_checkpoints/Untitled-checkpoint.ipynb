# %%
import json

# %%
# getting raw data
trial_data = []
debrief_data = []

for line in open('trials_data.json', 'r'):
    trial_data.append(json.loads(line))
for line in open('debriefs_data.json', 'r'):
    debrief_data.append(json.loads(line))

# %%
trial_data_room = {}
for trial in trial_data:
    id = trial["token_id"]
    room = trial["room"]
    if room not in trial_data_room.keys():
        trial_data_room[room] = {}
    if id not in trial_data_room[room].keys():
        trial_data_room[room][id] = []
    if trial not in trial_data_room[room][id]:
        trial_data_room[room][id].append(trial)

# %%
print(trial_data_token)
# Out:
# {'1bbLL': {'oOuiZCdlbbwrrFmDAAAD': [{'_id': {'$oid': '5e848423c259870016e1df3e'}, 'prior': [False, False, True, False, False, False, False, False], 'posterior': [False, False, False, False, False, False, False, True], 'disp_order': [15, 10, 11, 12, 8, 14, 13, 9], 'username': 'csassa', 'room': '1bbLL', 'trial': 1, 'data': [{'ids': [0, 1, 2], 'colours': ['red', 'green', 'red'], 'sizes': [2, 2, 1], 'xpos': [1.208259672834607, 1.2082596728346053, 3.6555627088626457], 'ypos': [4.128333333333334, 3.82748360469021, 3.8474172757652845], 'rotations': [3.1415926535897922, 3.14159265358979, 1.2121899680575183], 'orientations': ['upright', 'upright', 'lhs'], 'contact': [[0, 1], [1, 0], [2]], 'grounded': ['yes', 'no', 'yes'], 'follow_rule': True}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [2.8460878181304685], 'ypos': [4.124410150532198], 'rotations': [3.146339420374131], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': False}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [1.1537030718823027], 'ypos': [4.109090643963188], 'rotations': [3.094884541315517], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': False}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [0.3137145379836366], 'ypos': [4.124398002093109], 'rotations': [3.14455671668398], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': False}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [2.840444624459968], 'ypos': [4.100735007923345], 'rotations': [3.217411481271748], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': False}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [0.30802437737203914], 'ypos': [4.081127288181684], 'rotations': [3.0337087155496105], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['no'], 'follow_rule': False}, {'ids': [0], 'colours': ['red'], 'sizes': [1], 'xpos': [5.864980736341714], 'ypos': [4.122110096176511], 'rotations': [3.1339655326561178], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': True}, {'ids': [0], 'colours': ['blue'], 'sizes': [1], 'xpos': [1.1598251732259233], 'ypos': [4.1118910412876755], 'rotations': [3.1839289128055235], 'orientations': ['upright'], 'contact': [[0]], 'grounded': ['yes'], 'follow_rule': False}, {'ids': [0, 1, 2, 3], 'colours': ['red', 'green', 'green', 'red'], 'sizes': [1, 3, 1, 2], 'xpos': [4.99719497412721, 5.33966521510595, 6.7812617602386, 0.647214122653947], 'ypos': [3.87616110226316, 3.89757703212827, 4.15810225565523, 4.15717162300964], 'rotations': [1.21015432030723, 3.69203273094864, 3.14416974526282, 3.14125264303298], 'contact': [[0, 1], [1, 0], 2, 3], 'grounded': ['yes', 'yes', 'yes', 'yes']}, {'ids': [0, 1, 2, 3, 4], 'colours': ['red', 'red', 'blue', 'blue', 'green'], 'sizes': [2, 1, 2, 2, 1], 'xpos': [0.756045112876682, 5.7930538088619, 4.02912968049722, 0.607249611808554, 2.34445062198903], 'ypos': [3.78128677692435, 3.87663053995449, 3.77926220180112, 4.09987976609843, 4.15797989686201], 'rotations': [5.04734512360657, 1.21097145412816, 1.2338944765227, 2.99747085022243, 3.14330311350596], 'contact': [[0, 3], 1, 2, [3, 0], 4], 'grounded': ['yes', 'yes', 'yes', 'yes', 'yes']}, {'ids': [0, 1, 2, 3, 4, 5], 'colours': ['green', 'green', 'green', 'green', 'red', 'red'], 'sizes': [1, 1, 2, 2, 1, 1], 'xpos': [0.392205266119112, 6.46736091582645, 5.87132830651543, 2.56842478452184, 1.05497225772388, 3.35722507237469], 'ypos': [4.15754519774028, 3.87672651888649, 3.80774864689194, 4.15891117383473, 4.15835090526104, 4.15780493355124], 'rotations': [3.14560426344892, 5.07442800349693, 4.20513160762651, 3.14652142167178, 3.14300168792949, 3.1450254884391], 'contact': [0, [1, 2], [2, 1], 3, 4, 5], 'grounded': ['yes', 'yes', 'yes', 'yes', 'yes', 'yes']}, {'ids': [0, 1, 2], 'colours': ['blue', 'red', 'blue'], 'sizes': [1, 3, 1], 'xpos': [3.65329156447024, 3.06074315033349, 4.60711408951368], ' ...

# %%
print(3)
# Out:
# 3
